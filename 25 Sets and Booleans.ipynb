# %%
x = set()

# %%
x
# Out:
# set()

# %%
x.add(1)

# %%
x
# Out:
# {1}

# %%
x.add(2)

# %%
x.add("three")

# %%
x
# Out:
# {1, 2, 'three'}

# %%
x.add(2) # No change

# %%
x
# Out:
# {1, 2, 'three'}

# %% [markdown]
# We can cast a list for getting rid of multiple elements

# %%
l = [1,1,2,3,4,2,5,3,7,4]

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 7}

# %% [markdown]
# ### BOOLEANS

# %%
a = True

# %%
a
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
11 > 2
# Out:
# True

# %%
b = None

# %%
b

# %%
b = "hello"

# %%
b
# Out:
# 'hello'
